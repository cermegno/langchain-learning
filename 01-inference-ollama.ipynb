# %% [markdown]
# # Basic Ollama Inferencing

# %%
# %pip install -qU langchain-ollama --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import libraries

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# Initializing the model

# %%
llm = ChatOllama(
    model="gemma4:e4b",
    temperature=0.1,
)

# %% [markdown]
# Create a prompt to use with the chain

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI assistant."),
    ("user", "{input}")
    ])

# %% [markdown]
# Create the chain. This syntax replaces the old ```LLMchain()```

# %%
chain = prompt | llm

# %% [markdown]
# Test the chain with "invoke" method

# %%
response = chain.invoke({"input": "what is the colour of the sky?"})
print(response.content)
# Out:
# The color of the sky is **not always one single color**; it changes dramatically depending on the time of day, the weather, and the atmospheric conditions.
#
# However, here is a breakdown of the most common colors:
#
# ### ☀️ Daytime (The Most Common Answer)
# *   **Blue:** During clear daylight hours, the sky appears blue. This is due to a phenomenon called **Rayleigh scattering**. The Earth's atmosphere scatters shorter wavelengths of light (like blue and violet) more effectively than longer wavelengths (like red and orange), making the sky appear blue.
#
# ### 🌅 Sunrise and Sunset
# *   **Red, Orange, Pink, and Yellow:** When the sun is low on the horizon (sunrise or sunset), the light has to travel through much more of the Earth's atmosphere to reach your eyes. During this long journey, most of the blue light is scattered away, leaving the longer wavelengths—red, orange, and yellow—to dominate the view.
#
# ### ☁️ Cloudy Days
# *   **Gray or White:** When the sky is covered by thick clouds, the clouds scatter all the wavelengths of light equally, making the sky appear shades of gray or white.
#
# ### 🌃 Nighttime
# *   **Black (or Deep Indigo):** At night, without the direct light of the sun, the sky appears black. However, if you are far from city lights, you might see the faint glow of stars or the Milky Way, which can give it a deep, inky blue or black-purple hue.
#
# **In summary:** If you are asking about a typical, clear day, the answer is **blue**. But if you are watching the sun rise or set, the answer is likely **orange or red**!

# %%
print(response)
# Out:
# content="The color of the sky is **not always one single color**; it changes dramatically depending on the time of day, the weather, and the atmospheric conditions.\n\nHowever, here is a breakdown of the most common colors:\n\n### ☀️ Daytime (The Most Common Answer)\n*   **Blue:** During clear daylight hours, the sky appears blue. This is due to a phenomenon called **Rayleigh scattering**. The Earth's atmosphere scatters shorter wavelengths of light (like blue and violet) more effectively than longer wavelengths (like red and orange), making the sky appear blue.\n\n### 🌅 Sunrise and Sunset\n*   **Red, Orange, Pink, and Yellow:** When the sun is low on the horizon (sunrise or sunset), the light has to travel through much more of the Earth's atmosphere to reach your eyes. During this long journey, most of the blue light is scattered away, leaving the longer wavelengths—red, orange, and yellow—to dominate the view.\n\n### ☁️ Cloudy Days\n*   **Gray or White:** When the sky is covered by thick clouds, the clouds scatter all the wavelengths of light equally, making the sky appear shades of gray or white.\n\n### 🌃 Nighttime\n*   **Black (or Deep Indigo):** At night, without the direct light of the sun, the sky appears black. However, if you are far from city lights, you might see the faint glow of stars or the Milky Way, which can give it a deep, inky blue or black-purple hue.\n\n**In summary:** If you are asking about a typical, clear day, the answer is **blue**. But if you are watching the sun rise or set, the answer is likely **orange or red**!" additional_kwargs={} response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-05-01T05:08:33.9043084Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8679615800, 'load_duration': 275340900, 'prompt_eval_count': 30, 'prompt_eval_duration': 240632600, 'eval_count': 686, 'eval_duration': 7761972300, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'} id='lc_run--019de1f0-2602-7ac3-b04b-d5807e022af1-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 30, 'output_tokens': 686, 'total_tokens': 716}
